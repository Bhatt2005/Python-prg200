# %% [markdown]
# # 3- Inventory Restock Alert

# %%
# Karan Bhatt

inventory = [
    {"item": "Rice", "stock": 5, "threshold": 10},
    {"item": "Eggs", "stock": 24, "threshold": 12},
    {"item": "Milk", "stock": 3, "threshold": 6},
    {"item": "Bread", "stock": 8, "threshold": 5},
    {"item": "Chicken", "stock": 0, "threshold": 4},
    {"item": "Cooking Oil", "stock": 2, "threshold": 3},
]

count = 0

for item in inventory:
    if item["stock"] < item["threshold"]:
        print("Restock Alert:", item["item"], "| Stock:", item["stock"], "| Threshold:", item["threshold"])
        count += 1

print("Total items needing restock:", count)
# Out:
# Restock Alert: Rice | Stock: 5 | Threshold: 10
# Restock Alert: Milk | Stock: 3 | Threshold: 6
# Restock Alert: Chicken | Stock: 0 | Threshold: 4
# Restock Alert: Cooking Oil | Stock: 2 | Threshold: 3
# Total items needing restock: 4
