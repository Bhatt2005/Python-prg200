# %% [markdown]
# # 2- Water Level Alert System

# %%
#  Water Level Alert System (Koshi River)

sensors = [
    ("Chatara",         2.1),
    ("Tribeni Ghat",    4.4),
    ("Koshi Barrage",   5.1),
    ("Sunsari Bridge",  2.9),
    ("Saptakoshi Camp", 1.8),
]


def check_water_level(location, level_metres):
    if level_metres < 3:
        return "Safe"
    elif level_metres <= 5:
        return "Warning — Alert nearby villages"
    else:
        return "DANGER — Evacuate immediately!"


for location, level in sensors:
    status = check_water_level(location, level)
    print(f"{location} ({level} m): {status}")
# Out:
# Chatara (2.1 m): Safe
# Tribeni Ghat (4.4 m): Warning — Alert nearby villages
# Koshi Barrage (5.1 m): DANGER — Evacuate immediately!
# Sunsari Bridge (2.9 m): Safe
# Saptakoshi Camp (1.8 m): Safe
